# %%
import random

# %%
arr = []

# %%
for i in range(100_000):
    arr.append(random.randint(1,10000))

# %%
for i in range(100_000):
    arr.insert(1, i)

# %%
len(arr)
# Out:
# 100000

# %%
arr.sort()
